# %%
# International Stocks - VXUS, FTSE Global All Cap ex US Index: https://www.ftserussell.com/analytics/factsheets/home/search

# %%
import numpy as np
import pandas as pd
from PyPDF2 import PdfFileReader
import re
import datetime
import requests
import os

# %%
vxus_url = "https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false"

# %%
year = ''
month = ''
day = ''

# %%
cur_year = datetime.datetime.now().year
cur_year
# Out:
# 2020

# %%
error_url = 'https://www.ftserussell.com/products/indices/home/errorview?aspxerrorpath=/Analytics/FactSheets/Home/DownloadSingleIssueByDate'

# %%
quarterly_links = []

# %%
# Quarterly
for y in range(2018,cur_year+1):
    year = str(y)
    for m in range(1,13):
        if m < 10:
            month = '0'+ str(m)
        else:
            month = str(m)
        for d in range(28,32):
            day = str(d)
            date = year + month + day
            url = "https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate="+ date + "&IsManual=false.pdf"
            response = requests.get(url)
            if response.url != error_url:
                print(url)
                quarterly_links.append(url)
                break
# Out:
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180131&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180228&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180330&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180430&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180531&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180629&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180731&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180831&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180928&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181031&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181130&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181231&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190131&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190228&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190329&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190430&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190531&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190628&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190731&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190830&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190930&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191129&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191231&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200131&IsManual=false.pdf
# https://research.ftserussell.com/Analytics/FactSheets/Home/DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200228&IsManual=false.pdf

# %%
# Downloading files
for url in quarterly_links: 
    file_name = url.split('/')[-1]    
    print("Downloading file:%s"%file_name) 
    r = requests.get(url, stream = True) 
    with open(file_name, 'wb') as f: 
        for chunk in r.iter_content(chunk_size = 1024*1024): 
            if chunk: 
                f.write(chunk) 
    print("%s downloaded!\n"%file_name)
print("All reports downloaded!")
# Out:
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180131&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180228&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180330&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180330&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180430&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180430&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180531&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180531&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180629&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180629&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180731&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180731&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180831&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180831&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180928&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180928&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181031&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181031&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181130&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181130&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181231&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181231&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190131&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190228&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190329&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190329&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190430&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190430&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190531&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190531&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190628&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190628&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190731&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190731&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190830&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190830&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190930&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190930&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191129&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191129&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191231&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191231&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200131&IsManual=false.pdf downloaded!
#
# Downloading file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200228&IsManual=false.pdf downloaded!
#
# All reports downloaded!

# %%
file_names = []
for url in quarterly_links:
    file = url.split('/')[-1]
    file_names.append(file)

# %%
vxusDF = pd.DataFrame(columns=['File','MC'])
for x in range(len(file_names)):
    pdf = PdfFileReader(file_names[x])
    pdf_page = pdf.getPage(1)
    pdf_text = pdf_page.extractText()
    pdf_text = pdf_text.replace('\n',' ')
    pdf_text = pdf_text.replace('  ',' ')
    pdf_text = pdf_text.replace('  ',' ')
    mc = re.findall('Totals \d+ \d+,\d+,\d+', pdf_text, re.IGNORECASE)
    if mc == []:
        mc = 'n/a'
        row = [file_names[x],mc]
        vxusDF.loc[x] = row
        continue
    else:
        mc_1 = mc[0].replace(',','')
        mc_2 = mc_1.replace('\n','')
        mc_3 = mc_2.replace('Totals','')
        mc = [int(s) for s in mc_3.split() if s.isdigit()][1]
        row = [file_names[x],mc]
        vxusDF.loc[x] = row

# %%
vxusDF
# Out:
#                                                  File        MC
# 0   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  26346204
# 1   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25086513
# 2   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24838129
# 3   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25137377
# 4   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24471377
# 5   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24134257
# 6   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24637194
# 7   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24099318
# 8   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24205829
# 9   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22090263
# 10  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22250386
# 11  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  21226260
# 12  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22783955
# 13  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23189088
# 14  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23315381
# 15  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23825053
# 16  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22480285
# 17  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23889344
# 18  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23570617
# 19  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22798051
# 20  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23547228
# 21  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24378346
# 22  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24591817
# 23  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25734560
# 24  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24996509
# 25  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22955022

# %%
vxusDF['Name'] = np.nan
vxusDF
# Out:
#                                                  File        MC  Name
# 0   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  26346204   NaN
# 1   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25086513   NaN
# 2   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24838129   NaN
# 3   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25137377   NaN
# 4   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24471377   NaN
# 5   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24134257   NaN
# 6   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24637194   NaN
# 7   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24099318   NaN
# 8   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24205829   NaN
# 9   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22090263   NaN
# 10  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22250386   NaN
# 11  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  21226260   NaN
# 12  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22783955   NaN
# 13  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23189088   NaN
# 14  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23315381   NaN
# 15  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23825053   NaN
# 16  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22480285   NaN
# 17  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23889344   NaN
# 18  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23570617   NaN
# 19  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22798051   NaN
# 20  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23547228   NaN
# 21  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24378346   NaN
# 22  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24591817   NaN
# 23  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25734560   NaN
# 24  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24996509   NaN

# %%
vxusDF
# Out:
#                                                  File        MC  \
# 0   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  26346204
# 1   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25086513
# 2   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24838129
# 3   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25137377
# 4   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24471377
# 5   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24134257
# 6   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24637194
# 7   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24099318
# 8   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24205829
# 9   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22090263
# 10  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22250386
# 11  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  21226260
# 12  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22783955
# 13  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23189088
# 14  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23315381
# 15  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23825053
# 16  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22480285
# 17  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23889344
# 18  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23570617
# 19  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  22798051
# 20  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  23547228
# 21  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24378346
# 22  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24591817
# 23  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  25734560
# 24  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...  24996509
#
#                                                  Name
# 0   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 1   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 2   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 3   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 4   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 5   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 6   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 7   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 8   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 9   DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 10  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 11  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 12  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 13  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 14  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 15  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 16  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 17  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 18  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 19  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 20  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 21  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 22  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 23  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...
# 24  DownloadSingleIssueByDate?IssueName=GXUSS&Issu...

# %%
# Deleting files
for url in quarterly_links:
    file = url.split('/')[-1]
    print("Deleting file:%s"%file) 
    os.remove(file)
    print("%s deleted!\n"%file)
print("All reports deleted!")
# Out:
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180131&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180228&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180330&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180330&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180430&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180430&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180531&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180531&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180629&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180629&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180731&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180731&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180831&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180831&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180928&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20180928&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181031&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181031&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181130&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181130&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181231&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20181231&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190131&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190228&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190329&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190329&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190430&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190430&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190531&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190531&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190628&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190628&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190731&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190731&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190830&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190830&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190930&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20190930&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191031&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191129&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191129&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191231&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20191231&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200131&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200131&IsManual=false.pdf deleted!
#
# Deleting file:DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200228&IsManual=false.pdf
# DownloadSingleIssueByDate?IssueName=GXUSS&IssueDate=20200228&IsManual=false.pdf deleted!
#
# All reports deleted!
